# %%
import pandas as pd
import numpy as np
import statsmodels
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel('Correlacao_NPS_relacional.xlsx')

# %%
df.head(30)
# Out:
#           Mês        NPS  Giro de Carteira  Tx Concessão  Cadastro Atualizado  \
# 0  2023-09-30  55.508165           68227.0      0.007669               132489
# 1  2023-08-31  55.792428           60497.0      0.007498                76502
# 2  2023-07-31  56.342474           44454.0      0.007914                34527
# 3  2023-06-30  57.247045           40890.0      0.007817                36043
# 4  2023-05-31  57.088219           39088.0      0.008357                33921
# 5  2023-04-30  57.760096           54480.0      0.007662                33942
# 6  2023-03-31  57.983139           29435.0      0.008439                69725
# 7  2023-02-28  58.284003           21267.0      0.008207                23808
# 8  2023-01-31  58.387824           24386.0      0.007453                25478
# 9  2022-12-31  58.315586           20263.0      0.008463                26714
# 10 2022-11-30  58.934212           17301.0      0.007568                22205
# ...

# %%
data_types = df.dtypes
valores_ausentes = df.isnull().sum()
estatisticas_df = df.describe()

# %%
print('Data Types:\n', data_types)
print('-----------------------------------')
print('Valores Ausentes:\n', valores_ausentes)
print('-----------------------------------')
print('Estatística Descritiva:\n', estatisticas_df)
# Out:
# Data Types:
#  Mês                                    datetime64[ns]
# NPS                                           float64
# Giro de Carteira                              float64
# Tx Concessão                                  float64
# Cadastro Atualizado                             int64
# Tempo de Fila                                 float64
# Tempo de Atendimento                          float64
# Vinculação Boa                                  int64
# Vinculação Média                                int64
# Vinculação Baixa                                int64
# Vinculação Baixissima                           int64
# Nivel de serviço                              float64
# Auto atendimento                              float64
# Volume Inativo e Pré inativo                    int64
# Coop desligamento Bacen                       float64
# Consumo do Cartão                             float64
# Limite Credito x Motor                        float64
# ...

# %% [markdown]
# ### Tratando valores ausentes

# %%
# eliminando colunas com mais de 30% de valores ausentes

percentual_ausentes = df.isnull().mean()*100

elimina_colunas = percentual_ausentes[percentual_ausentes > 30].index

df_limpo = df.drop(columns=elimina_colunas)

print('Colunas Removidas:', elimina_colunas)
print('')
